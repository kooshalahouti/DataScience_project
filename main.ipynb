# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       11/26/2013   26  November  2013            19     Youth (<25)
# 1       11/26/2015   26  November  2015            19     Youth (<25)
# 2        3/23/2014   23     March  2014            49  Adults (35-64)
# 3        3/23/2016   23     March  2016            49  Adults (35-64)
# 4        5/15/2014   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031   4/12/2016   12     April  2016            41  Adults (35-64)
# 113032    4/2/2014    2     April  2014            18     Youth (<25)
# 113033    4/2/2016    2     April  2016            18     Youth (<25)
# 113034    3/4/2014    4     March  2014            37  Adults (35-64)
# 113035    3/4/2016    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %% [markdown]
# getting the shape (number of rows and number of columns) of the csv file

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  11/26/2013   26  November  2013            19     Youth (<25)
# 1  11/26/2015   26  November  2015            19     Youth (<25)
# 2   3/23/2014   23     March  2014            49  Adults (35-64)
# 3   3/23/2016   23     March  2016            49  Adults (35-64)
# 4   5/15/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# describe method is a convenient way to get a quick overview of your data such as the count of that column or the mean and etc. Also it is a great method for summarize the data frame.

# %%
df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %% [markdown]
# The info method in Pandas provides a concise summary of a DataFrame's structure, including the number of columns, their labels, data types, non-null counts, and memory usage

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %% [markdown]
# Name of the columns

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
df["Product_Category"].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %% [markdown]
# Count the categories based on gender.

# %%
df.groupby("Customer_Gender")["Product_Category"].value_counts()
# Out:
# Customer_Gender  Product_Category
# F                Accessories         33844
#                  Bikes               12852
#                  Clothing             8028
# M                Accessories         36276
#                  Bikes               13130
#                  Clothing             8906
# Name: count, dtype: int64

# %% [markdown]
# use groupby method and value count for count the values of countries based on gender.

# %%
df.groupby("Customer_Gender")["Country"].value_counts()
# Out:
# Customer_Gender  Country
# F                United States     18934
#                  Australia         11506
#                  United Kingdom     6712
#                  Canada             6496
#                  Germany            5572
#                  France             5504
# M                United States     20272
#                  Australia         12430
#                  Canada             7682
#                  United Kingdom     6908
#                  Germany            5526
#                  France             5494
# Name: count, dtype: int64

# %% [markdown]
# Drop the duplicate elements.

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (112036, 18)

# %% [markdown]
# Missing Values

# %%
pd.DataFrame([df.isnull().sum(), df.isnull().sum() / df.shape[0] * 100], index=['count', '%']).T
# Out:
#                   count    %
# Date                0.0  0.0
# Day                 0.0  0.0
# Month               0.0  0.0
# Year                0.0  0.0
# Customer_Age        0.0  0.0
# Age_Group           0.0  0.0
# Customer_Gender     0.0  0.0
# Country             0.0  0.0
# State               0.0  0.0
# Product_Category    0.0  0.0
# Sub_Category        0.0  0.0
# Product             0.0  0.0
# Order_Quantity      0.0  0.0
# Unit_Cost           0.0  0.0
# Unit_Price          0.0  0.0
# Profit              0.0  0.0
# Cost                0.0  0.0
# Revenue             0.0  0.0

# %%
df["Customer_Gender"].value_counts()
# Out:
# Customer_Gender
# M    57813
# F    54223
# Name: count, dtype: int64

# %% [markdown]
# Data Visualization

# %%
(df.groupby("Country")["Cost"].mean().sort_values(ascending=False).plot(kind="bar", xlabel="Country", ylabel="Cost", title="Costs in Countries"))
# Out:
# <Axes: title={'center': 'Costs in Countries'}, xlabel='Country', ylabel='Cost'>

# %%
(df.groupby("Product_Category")["Cost"].mean().sort_values(ascending=False).plot(kind="bar", xlabel="Product Category", ylabel="Cost", title="Costs in States"))
# Out:
# <Axes: title={'center': 'Costs in States'}, xlabel='Product Category', ylabel='Cost'>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(df["Month"])
plt.xlabel("Number of Transaction")
plt.ylabel("Month")
plt.title("Monthly Transaction")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.set(style='ticks', font_scale=1)

sns.countplot(data=df, x='Country', hue='Product_Category').set_title('Countries by Count based on Product_Category')

sns.despine()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(df["Customer_Gender"])
plt.xlabel("Number of Transaction")
plt.ylabel("Gender")
plt.title("Gender Transaction")
# Out:
# Text(0.5, 1.0, 'Gender Transaction')

# %%
sns.countplot(data=df, x="Country", hue="Customer_Gender", palette=('winter'))
plt.xticks(rotation=60)
sns.set_style("whitegrid")
plt.legend(['Male', 'Female'])
plt.gcf().set_size_inches(11, 6)
plt.show()

# %%
df[['Customer_Age', 'Cost', 'Revenue', 'Order_Quantity']].hist(bins=50, figsize=(10,5), color='blue')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.title('Product Category vs price')
sns.scatterplot(x=df['Product_Category'], y=df['Unit_Price'], hue=df['Country'])
plt.xlabel('product category')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.countplot(y='State', data=df)
plt.title('Model Types')
plt.show()

# %%
plt.figure(figsize=(8, 8))
sns.set(font_scale=1.2)
sns.heatmap(df[["Customer_Age", "Order_Quantity", "Profit", "Unit_Cost",  "Unit_Price"]].corr(), square=True, annot=True)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(7,5))
plt.title('Correlation between year and price')
sns.regplot(x='Cost', y='Revenue', data=df)
# Out:
# <Axes: title={'center': 'Correlation between year and price'}, xlabel='Cost', ylabel='Revenue'>

# %% [markdown]
# Detecting Outliers

# %%
sns.boxplot(x=df["Unit_Price"])
# Out:
# <Axes: xlabel='Unit_Price'>

# %%
sns.boxplot(df["Profit"])
# Out:
# <Axes: ylabel='Profit'>

# %%
sns.boxplot(df["Revenue"])
# Out:
# <Axes: ylabel='Revenue'>

# %%
fig = plt.figure(figsize=(7,7))
colors = ("gold", "red", "yellowgreen")
wp = {'linewidth':2, 'edgecolor':"black"}
tags = df['Product_Category'].value_counts()
explode= (0.1, 0.1, 0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors = colors, startangle=90, 
          wedgeprops = wp, explode=explode, label='')
plt.title('Product Category')
plt.show()

# %%
Accessories = df[df['Product_Category'] == 'Accessories']
df_Accessories = Accessories['Sub_Category'].value_counts()

label = [df_Accessories.index.tolist()]
plt.pie(df_Accessories, autopct='%1.1f%%',labels=label[0])
plt.gcf().set_size_inches(12,6)

# %%
df_Country=df['Country'].value_counts()
label= [df_Country.index.tolist()]
plt.pie(df_Country,
        labels=label[0],
       autopct='%1.1f%%'
       )
plt.title("Country")
plt.gcf().set_size_inches(12,6)

# %%
df.plot(kind = 'scatter', x='Year', y = 'Cost', alpha = 0.5, color = 'y')
plt.xlabel("year")
plt.ylabel("price")
plt.title("year - price Scatter Plot")
plt.show()

# %% [markdown]
# Using Linear Regression for prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.preprocessing import StandardScaler,PolynomialFeatures
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df.duplicated().values.any()
# Out:
# False

# %%
df.dtypes
# Out:
# Date                object
# Day                  int64
# Month               object
# Year                 int64
# Customer_Age         int64
# Age_Group           object
# Customer_Gender     object
# Country             object
# State               object
# Product_Category    object
# Sub_Category        object
# Product             object
# Order_Quantity       int64
# Unit_Cost            int64
# Unit_Price           int64
# Profit               int64
# Cost                 int64
# Revenue              int64
# dtype: object

# %%
df.drop('Order_Quantity',axis =1,inplace=True)
df.drop('Unit_Cost',axis =1,inplace=True)
df.drop('Unit_Price',axis =1,inplace=True)
df.drop('Revenue',axis =1,inplace=True)

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  11/26/2013   26  November  2013            19     Youth (<25)
# 1  11/26/2015   26  November  2015            19     Youth (<25)
# 2   3/23/2014   23     March  2014            49  Adults (35-64)
# 3   3/23/2016   23     March  2016            49  Adults (35-64)
# 4   5/15/2014   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Profit  Cost
# 0  Hitch Rack - 4-Bike     590   360
# ...

# %%
Bike=df.select_dtypes(exclude=['object']).copy()
Bike.head()
# Out:
#    Day  Year  Customer_Age  Profit  Cost
# 0   26  2013            19     590   360
# 1   26  2015            19     590   360
# 2   23  2014            49    1366  1035
# 3   23  2016            49    1188   900
# 4   15  2014            47     238   180

# %%
Bike['Customer_Age'] = df['Customer_Age']
Bike['Customer_Gender'] = df['Customer_Gender']
Bike['Country'] = df['Country']
Bike['Product_Category'] = df['Product_Category']
Bike.head()
# Out:
#    Day  Year  Customer_Age  Profit  Cost Customer_Gender    Country  \
# 0   26  2013            19     590   360               M     Canada
# 1   26  2015            19     590   360               M     Canada
# 2   23  2014            49    1366  1035               M  Australia
# 3   23  2016            49    1188   900               M  Australia
# 4   15  2014            47     238   180               F  Australia
#
#   Product_Category
# 0      Accessories
# 1      Accessories
# 2      Accessories
# 3      Accessories
# 4      Accessories

# %%
Bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112036 entries, 0 to 113035
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Day               112036 non-null  int64
#  1   Year              112036 non-null  int64
#  2   Customer_Age      112036 non-null  int64
#  3   Profit            112036 non-null  int64
#  4   Cost              112036 non-null  int64
#  5   Customer_Gender   112036 non-null  object
#  6   Country           112036 non-null  object
#  7   Product_Category  112036 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 7.7+ MB

# %%
Bike=pd.get_dummies(Bike)
Bike.head()
# Out:
#    Day  Year  Customer_Age  Profit  Cost  Customer_Gender_F  \
# 0   26  2013            19     590   360              False
# 1   26  2015            19     590   360              False
# 2   23  2014            49    1366  1035              False
# 3   23  2016            49    1188   900              False
# 4   15  2014            47     238   180               True
#
#    Customer_Gender_M  Country_Australia  Country_Canada  Country_France  \
# 0               True              False            True           False
# 1               True              False            True           False
# 2               True               True           False           False
# 3               True               True           False           False
# 4              False               True           False           False
#
#    Country_Germany  Country_United Kingdom  Country_United States  \
# 0            False                   False                  False
# ...

# %%
Bike.shape
# Out:
# (112036, 16)

# %%
X, y = Bike.drop('Profit',axis=1), Bike['Profit']

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.2, random_state=100)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.25, random_state=100)

# %%
X_train_val.head()
# Out:
#        Day  Year  Customer_Age  Cost  Customer_Gender_F  Customer_Gender_M  \
# 34965   13  2016            62    39              False               True
# 87667    3  2016            26    32               True              False
# 41461    9  2016            41    52              False               True
# 49369    4  2016            50  5736               True              False
# 46176    7  2014            28   950              False               True
#
#        Country_Australia  Country_Canada  Country_France  Country_Germany  \
# 34965              False           False           False            False
# 87667               True           False           False            False
# 41461              False           False           False            False
# 49369               True           False           False            False
# 46176              False           False           False            False
#
#        Country_United Kingdom  Country_United States  \
# ...

# %%
X_test.head()
# Out:
#        Day  Year  Customer_Age  Cost  Customer_Gender_F  Customer_Gender_M  \
# 15717    9  2015            22    30               True              False
# 24462    3  2013            34    56              False               True
# 93532   20  2014            17   143              False               True
# 60870    4  2014            44   344              False               True
# 42346   23  2014            29   462               True              False
#
#        Country_Australia  Country_Canada  Country_France  Country_Germany  \
# 15717               True           False           False            False
# 24462              False           False           False            False
# 93532              False           False           False            False
# 60870              False           False           False            False
# 42346              False           False           False            False
#
#        Country_United Kingdom  Country_United States  \
# ...

# %%
y_train_val.head()
# Out:
# 34965      64
# 87667      38
# 41461      57
# 49369    3138
# 46176     250
# Name: Profit, dtype: int64

# %%
y_train.head()
# Out:
# 39912     170
# 9320       90
# 39026     238
# 70114     576
# 111043    854
# Name: Profit, dtype: int64

# %% [markdown]
# Computes the R² score (coefficient of determination) for the training data

# %%
lm = LinearRegression().fit(X_train, y_train)
print(lm.score(X_train, y_train))
# Out:
# 0.8272720241402746

# %% [markdown]
# It transforms the data so that each feature has:
# A mean of 0.
# A standard deviation of 1
# <br />
# transform():
# Uses the mean and standard deviation calculated during the fit step (from X_train) to standardize the validation and test datasets.

# %%
scaler = StandardScaler()

X_train_scaled =scaler.fit_transform(X_train.values)
X_val_scaled = scaler.transform(X_val.values)
X_test_scaled = scaler.transform(X_test.values)

lm = LinearRegression().fit(X_train_scaled,y_train)
lm.score(X_train_scaled,y_train)
# Out:
# 0.8272694545605255

# %%
poly = PolynomialFeatures(degree=3) 

X_train_poly = poly.fit_transform(X_train.values)
X_val_poly = poly.transform(X_val.values)
X_test_poly = poly.transform(X_test.values)

lm_poly = LinearRegression().fit(X_train_poly,y_train)
lm_poly.score (X_train_poly,y_train)
# Out:
# 0.8942571278053826

# %% [markdown]
# PCA

# %%
from sklearn.decomposition import PCA

# %%
x = df.iloc[:, :len(df.columns) - 1]
y = df["Cost"]
X
# Out:
#         Day  Year  Customer_Age  Cost  Customer_Gender_F  Customer_Gender_M  \
# 0        26  2013            19   360              False               True
# 1        26  2015            19   360              False               True
# 2        23  2014            49  1035              False               True
# 3        23  2016            49   900              False               True
# 4        15  2014            47   180               True              False
# ...     ...   ...           ...   ...                ...                ...
# 113031   12  2016            41    72              False               True
# 113032    2  2014            18   528              False               True
# 113033    2  2016            18   528              False               True
# 113034    4  2014            37   576               True              False
# 113035    4  2016            37   552               True              False
#
# ...

# %%
sc = StandardScaler()
Xs = sc.fit_transform(X)

# %%
components = 14
pca = PCA(n_components=components)
X_new = pca.fit_transform(Xs)

# %%
fig, ax =  plt.subplots(1, 2, figsize=(10, 5))
ax[0].scatter(X.iloc[:, 0], X.iloc[:, 1], c=y)
ax[0].set_xlabel('x1')
ax[0].set_ylabel('x2')
ax[0].set_title('Before PCA')
ax[1].scatter(X_new[:,0], X_new[:,1], c=y)
ax[1].set_xlabel('PC1')
ax[1].set_ylabel('PC2')
ax[1].set_title('After PCA')
plt.show()

# %%
print("Explained Variances (%): ")
print(pca.explained_variance_ratio_ * 100)
print()
# Out:
# Explained Variances (%):
# [1.62503702e+01 1.33464662e+01 9.64565235e+00 9.01008211e+00
#  8.02151311e+00 7.54286794e+00 7.46440023e+00 7.39335098e+00
#  6.69909976e+00 6.43753022e+00 5.76787082e+00 2.42079609e+00
#  1.80161813e-15 0.00000000e+00]

# %%
print("Cumulative Explained Variances (%):")
print(pca.explained_variance_ratio_.cumsum() * 100)
print()
# Out:
# Cumulative Explained Variances (%):
# [ 16.25037021  29.59683639  39.24248874  48.25257085  56.27408396
#   63.8169519   71.28135213  78.67470311  85.37380287  91.81133309
#   97.57920391 100.         100.         100.        ]

# %%
components = len(pca.explained_variance_ratio_) if components is None else components
plt.figure(figsize = (20,15))
plt.plot(range(1,components+1), pca.explained_variance_ratio_, color='tab:blue', marker='o')
plt.xlabel("Number of components", fontsize=25)
plt.ylabel("Explained variance (%)", fontsize=25)
plt.grid()

# %%
def biplot(score, coeff , y):
    xs = score[:,0]
    ys = score[:,1]
    n = 5 
    plt.figure(figsize=(10,8), dpi=50)
    classes = np.unique(y)
    colors = ['g','r','y']
    markers=['o','^','x']
    zoom=3
    for s,l in enumerate(classes):
        plt.scatter(xs[y==l],ys[y==l])
    for i in range(n):
       
        plt.arrow(0, 0, coeff[i,0] * zoom, coeff[i,1] * zoom, color = 'k', alpha = 0.9,linestyle = '-',linewidth = 1.5, overhang=0.2)
        plt.text(coeff[i,0]* zoom, coeff[i,1] * zoom, "Var"+str(i+1), color = 'k', ha = 'center', va = 'center',fontsize=10)

    plt.xlabel("PC{}".format(1), size=14)
    plt.ylabel("PC{}".format(2), size=14)
    limx= int(xs.max()) + 1
    limy= int(ys.max()) + 1
    plt.xlim([-limx,limx])
    plt.ylim([-limy,limy])
    plt.grid()
    plt.tick_params(axis='both', which='both', labelsize=14)


import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)

biplot(X_new[:,0:2], np.transpose(pca.components_[0:2, :]), y)
plt.show()
